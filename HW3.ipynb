# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
#whale_returns_csv = Path("whale_returns.csv")
whale_returns_csv = Path("Resources/whale_returns.csv")
data1=pd.read_csv(whale_returns_csv)
data1.set_index(pd.to_datetime(data1['Date'], infer_datetime_format=True), inplace=True)
data1.drop(columns=['Date'], inplace=True)
data1.head()

# YOUR CODE HERE
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
# YOUR CODE HERE
data1.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
data1 = data1.dropna()
data1.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
#algo_returns_csv = Path("algo_returns.csv")
algo_returns_csv = Path("Resources/algo_returns.csv")
# YOUR CODE HERE
data2=pd.read_csv(algo_returns_csv)
data2.set_index(pd.to_datetime(data2['Date'], infer_datetime_format=True), inplace=True)
data2.drop(columns=['Date'], inplace=True)
data2.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
# YOUR CODE HERE
data2.isna().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
data2 = data2.dropna()
data2.isna().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
#sp500_history_csv = Path("sp500_history.csv")
sp500_history_csv = Path("Resources/sp500_history.csv")
# YOUR CODE HERE
data3=pd.read_csv(sp500_history_csv)
data3.set_index(pd.to_datetime(data3['Date'], infer_datetime_format=True), inplace=True)
data3.drop(columns=['Date'], inplace=True)
data3.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
# YOUR CODE HERE
data3.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
# YOUR CODE HERE
data3['Close'] = data3['Close'].str.replace('$','').astype(np.float64)
data3.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
# YOUR CODE HERE
data3 = data3.pct_change()
data3.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
# YOUR CODE HERE
data3 = data3.dropna()
data3.head()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
# Rename Column
# YOUR CODE HERE
data3.rename(columns={'Close':'S&P 500'}, inplace=True)
data3.head()
# Out:
#              S&P 500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
# YOUR CODE HERE
frames = [data1, data2, data3]
data123 = pd.concat(frames,axis="columns", join="inner")
data123.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns.

# %%
# Plot daily returns
# YOUR CODE HERE
data123.plot(figsize=(15,8))

# %%
# Plot cumulative returns
# YOUR CODE HERE
cumulative_returns = (1 + data123).cumprod()
cumulative_returns.head()
cumulative_returns.plot(figsize=(15,8))

# %% [markdown]
# ---

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
# YOUR CODE HERE
data123.boxplot(figsize=(19,8))

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. Which portfolios are riskier than the S&P 500?
# YOUR CODE HERE
data123.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# S&P 500                        0.008587
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
# YOUR CODE HERE
data123.std()>data123['S&P 500'].std()
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# dtype: bool

# %%
# Calculate the annualized standard deviation (252 trading days)
# YOUR CODE HERE
data123.std()*(252)**(1/2)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# S&P 500                        0.136313
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&PP 500 using a 21 day window
# 2. Calcualte the correlation between each stock to determine which portfolios may mimick the S&P 500
# 2. Calculate and plot a 60 day Beta for Berkshire Hathaway Inc compared to the S&&P 500

# %%
# Calculate and plot the rolling standard deviation for the S&PP 500 using a 21 day window
# YOUR CODE HERE
data123_rolling= data123.rolling(window=21).std()
data123_rolling.plot(figsize=(19,8))

# %%
# Correlation
# YOUR CODE HERE
data123.corr()
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# S&P 500                                       0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# ...

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# YOUR CODE HERE
import matplotlib.pyplot as pl
rolling_covariance = data123['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(data123['S&P 500'])
rolling_variance = data123['S&P 500'].rolling(window=60).cov(data123['S&P 500'])
beta=rolling_covariance/rolling_variance
beta.plot(figsize=(19,8))
pl.title('BERKSHIRE HATHAWAY INC beta')
# Out:
# Text(0.5, 1.0, 'BERKSHIRE HATHAWAY INC beta')

# %% [markdown]
# ### Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rollwing window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the `ewm` with a 21 day half-life.

# %%
# (OPTIONAL) YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# Calculate and plot the annualized Sharpe ratios for all portfolios to determine which portfolio has the best performance

# %%
# Annualzied Sharpe Ratios
# YOUR CODE HERE
SR=(data123.mean() * 252) / (data123.std() * np.sqrt(252))
SR
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# S&P 500                       -0.518582
# dtype: float64

# %% [markdown]
#  plot() these sharpe ratios using a barplot.
#  On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales?

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE
SR.plot(kind="bar", title="Sharpe Ratios")

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
# YOUR CODE HERE
data4=pd.read_csv('goog_historical.csv')
data4.set_index(pd.to_datetime(data4['Trade DATE'], infer_datetime_format=True), inplace=True)
data4.drop(columns=['Trade DATE'], inplace=True)
data4.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Read the second stock
# YOUR CODE HERE
data5=pd.read_csv('aapl_historical.csv')
data5.set_index(pd.to_datetime(data5['Trade DATE'], infer_datetime_format=True), inplace=True)
data5.drop(columns=['Trade DATE'], inplace=True)
data5.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
# Read the third stock
# YOUR CODE HERE
data6=pd.read_csv('cost_historical.csv')
data6.set_index(pd.to_datetime(data6['Trade DATE'], infer_datetime_format=True), inplace=True)
data6.drop(columns=['Trade DATE'], inplace=True)
data6.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
# Concatenate all stocks into a single DataFrame
# YOUR CODE HERE
frames = [data4, data5, data6]
data456 = pd.concat(frames,axis="rows", join="inner")
data456.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Reset the index
# YOUR CODE HERE
data456=data456.reset_index()
data456.head()
# Out:
#   Trade DATE Symbol     NOCP
# 0 2019-05-09   GOOG  1162.38
# 1 2019-05-08   GOOG  1166.27
# 2 2019-05-07   GOOG  1174.10
# 3 2019-05-06   GOOG  1189.39
# 4 2019-05-03   GOOG  1185.40

# %%
# Pivot the Data so that the stock tickers are the columns, the dates are the index, and the 
# values are the closing prices
# YOUR CODE HERE
data456_pivot=data456.pivot(index='Trade DATE',columns='Symbol',values='NOCP')
data456_pivot.head()
# Out:
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Drop Nulls
# YOUR CODE HERE
daily_returns = data456_pivot.pct_change()
daily_returns = daily_returns.dropna()
daily_returns.head()
# Out:
# Symbol          AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
# YOUR CODE HERE
portfolio_returns = daily_returns.dot(weights)
portfolio_returns.head()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# YOUR CODE HERE
frames = [data123, portfolio_returns]
data_all = pd.concat(frames,axis="columns", join="inner")
data_all.rename(columns={0:'Custom'}, inplace=True)
data_all.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2019-04-15                     0.000398               -0.010492 -0.004331
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
#
#               Algo 2   S&P 500    Custom
# 2019-04-15 -0.004572 -0.000509  0.007522
# 2019-04-16  0.002899  0.002279  0.000340
# 2019-04-17 -0.005228 -0.001577  0.009292
# ...

# %%
# Only compare dates where the new, custom portfolio has dates
# YOUR CODE HERE

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
# YOUR CODE HERE
data_all.std()*(252)**(1/2)
# Out:
# SOROS FUND MANAGEMENT LLC      0.146812
# PAULSON & CO.INC.              0.116928
# TIGER GLOBAL MANAGEMENT LLC    0.232898
# BERKSHIRE HATHAWAY INC         0.247305
# Algo 1                         0.133927
# Algo 2                         0.139499
# S&P 500                        0.152469
# Custom                         0.211627
# dtype: float64

# %%
# Rolling
# YOUR CODE HERE
data_all_rolling= data_all.rolling(window=21).std()
data_all_rolling.plot(figsize=(19,8))

# %%
# Beta
# YOUR CODE HERE
rolling_covariance = data_all['Custom'].rolling(window=60).cov(data_all['S&P 500'])
rolling_variance = data_all['S&P 500'].rolling(window=60).cov(data_all['S&P 500'])
beta=rolling_covariance/rolling_variance
beta.plot(figsize=(19,8))
pl.title('Custom beta')
# Out:
# Text(0.5, 1.0, 'Custom beta')

# %%
# Annualzied Sharpe Ratios
# YOUR CODE HERE
SR=(data_all.mean() * 252) / (data_all.std() * np.sqrt(252))
SR
# Out:
# SOROS FUND MANAGEMENT LLC      0.380007
# PAULSON & CO.INC.              0.227577
# TIGER GLOBAL MANAGEMENT LLC   -1.066635
# BERKSHIRE HATHAWAY INC         0.103006
# Algo 1                         2.001260
# Algo 2                         0.007334
# S&P 500                       -0.427676
# Custom                         0.876152
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE
SR.plot(kind="bar", title="Sharpe Ratios")

# %% [markdown]
# ## Include correlation analysis to determine which stocks (if any) are correlated

# %%
# YOUR CODE HERE
data_all.corr()
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.791802
# PAULSON & CO.INC.                             0.791802            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.477844            0.484869
# BERKSHIRE HATHAWAY INC                        0.816197            0.650390
# Algo 1                                        0.336909            0.360727
# Algo 2                                        0.862583            0.783865
# S&P 500                                      -0.028256           -0.059862
# Custom                                        0.732548            0.643828
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.477844
# PAULSON & CO.INC.                               0.484869
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.324306
# ...
